# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

gc_mw = np.genfromtxt("glob_cus.dat", skip_header=3, skip_footer=362)[:,2]
gc_m31 = np.genfromtxt("glob_cus.dat", skip_header=89)[:,1] - 22.4

# %%
count, bins, ignored = plt.hist(gc_mw, 50, alpha = 0.8, normed = True)
count2, bins2, ignored2 = plt.hist(gc_m31, 50, alpha = 0.8, normed = True)

# %%
res = stats.probplot(gc_mw, plot=plt)
res2 = stats.probplot(gc_m31, plot=plt)
